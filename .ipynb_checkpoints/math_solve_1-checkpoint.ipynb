# %% [markdown]
# Problem:İlk terimi $a_1 = 3$ ve ortak farkı $d = 5$ olan bir aritmetik dizinin: İlk 10 terimini listeleyin 15. terimi ($a_{15}$) terimini
# bulun.İlk 15 terimin toplamını ($S_{15}$) hesaplayın.(Aritmetik Dizi Formülleri: $a_n = a_1 + (n-1)d$ ve $S_n = \frac{n}{2}(a_1 + a_n)$)

# %% [markdown]
# Problem:İlk terimi $a_1 = 2$ ve ortak çarpanı $r = 3$ olan bir geometrik dizinin:İlk 6 terimini ekrana yazdırın.terimini ($a_8$) bulun.(Geometrik Dizi Formülü: $a_n = a_1 \cdot r^{n-1}$)

# %% [markdown]
# Problem:İlk iki terimi $1, 1$ olan ve her terimi kendinden önceki iki terimin toplamına eşit olan Fibonacci dizisinin ilk 12 terimini listeleyin.(Formül: $F_1 = 1, F_2 = 1, F_n = F_{n-1} + F_{n-2}$)
