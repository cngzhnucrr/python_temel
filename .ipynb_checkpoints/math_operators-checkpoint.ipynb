# %% [markdown]
# *  "+"--> toplama
# *  "-" --> çıkarma
# *  "*" --> çarpma
# *  "/"--> bölme
# *  "**" --> üs alma
# *  "%" --> mod alma
# *  "//" --> tam bölme  , tam kısmını verir sadece

# %%
2*2
# Out:
# 4

# %%
print(2*2)
# Out:
# 4

# %%
x=20/2.0

# %%
x
# Out:
# 10.0

# %%
type(x)
# Out:
# float

# %%
10%2
# Out:
# 0

# %%
10%3
# Out:
# 1

# %%
10//3
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335
