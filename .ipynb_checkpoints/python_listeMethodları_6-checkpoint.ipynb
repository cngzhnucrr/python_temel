# %%
numbers=[1,10,5,16,4,9,10]
letters=['a','g','s','b','y','a','s']

# %%
val_1=min(numbers)
print(val_1)
val_2=max(numbers)
print(val_2)
val_3=min(letters)
print(val_3)
val_4=max(letters)
print(val_4)
# Out:
# 1
# 16
# a
# y

# %%
numbers[3]=50

# %%
print(max(numbers))
# Out:
# 50

# %% [markdown]
# görüldüğü gibi listelerde listenin herhangi bir elemanı güncellenebilir ama güncellenemeyen listeler de mevcuttur.

# %%
ekle=11
numbers.append(ekle)

# %%
ekle= 10, 17
numbers.append(ekle)

# %%
print(numbers)
# Out:
# [1, 10, 5, 50, 4, 9, 10, (10, 17), 11, 11, (10, 17)]

# %%
print(type(numbers[7]))
# Out:
# <class 'tuple'>

# %% [raw]
# 5 in soluna 15 sayısını eklemek istiyorum diyelim

# %%
numbers.insert(2,15)

# %%
print(numbers)
# Out:
# [1, 10, 15, 5, 50, 4, 9, 10, (10, 17), 11, 11, (10, 17)]

# %%
numbers.pop()
# Out:
# (10, 17)

# %%
print(numbers)
# Out:
# [1, 10, 15, 5, 50, 4, 9, 10, (10, 17), 11, 11]

# %%
numbers.insert(-1,11)

# %%
print(numbers)
# Out:
# [1, 10, 15, 5, 50, 4, 9, 10, (10, 17), 11, 11, 11]

# %%
numbers.pop()
# Out:
# 11

# %%
print(numbers)
# Out:
# [1, 10, 15, 5, 50, 4, 9, 10, (10, 17), 11, 11]

# %%
numbers.pop(-1)
# Out:
# 11

# %%
print(numbers)
# Out:
# [1, 10, 15, 5, 50, 4, 9, 10, (10, 17), 11]

# %%
numbers.remove(50)

# %%
print(numbers)
# Out:
# [1, 10, 15, 5, 4, 9, 10, (10, 17), 11]

# %%
numbers.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 numbers.sort()
#
# TypeError: '<' not supported between instances of 'tuple' and 'int'

# %%
numbers.remove((10,17))

# %%
print(numbers)
# Out:
# [1, 4, 5, 9, 10, 10, 15, 11]

# %%
numbers.sort()

# %%
print(numbers)
# Out:
# [1, 4, 5, 9, 10, 10, 11, 15]

# %%
numbers.reverse()

# %%
print(numbers)
# Out:
# [15, 11, 10, 10, 9, 5, 4, 1]

# %%
letters.sort()

# %%
print(letters)
# Out:
# ['a', 'a', 'b', 'g', 's', 's', 'y']

# %%
letters.reverse()

# %%
print(letters)
# Out:
# ['y', 's', 's', 'g', 'b', 'a', 'a']

# %%
print(numbers.count(2))
# Out:
# 0

# %%
print(numbers.count(10))
# Out:
# 2

# %%
print(numbers)
# Out:
# [15, 11, 10, 10, 9, 5, 4, 1]

# %%
list= [1,2,3,4]
tuple= 1,"iki",3

# %%
list[0]=8

# %%
print(list)
# Out:
# [8, 2, 3, 4]

# %%
tuple(0)=8
# Out:
#   Cell In[60], line 1
#     tuple(0)=8
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %% [markdown]
# listelerde eleman yerie atama yapılabilri ama tuple veri tipinde atama yapılamaz

# %%
tuple.count(1)
# Out:
# 1

# %%
print(10//3.0)
# Out:
# 3.0

# %%
print(0.1+0.2)
# Out:
# 0.30000000000000004
